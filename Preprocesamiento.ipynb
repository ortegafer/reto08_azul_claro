# %%
import pandas as pd
import statistics
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
c_a=pd.read_csv("../Datos/Originales/Compresores/CompA.csv")
c_b=pd.read_csv("../Datos/Originales/Compresores/CompB.csv")
c_c=pd.read_csv("../Datos/Originales/Compresores/CompC.csv")
c_d=pd.read_csv("../Datos/Originales/Compresores/CompD.csv")

# %%
#Juntamos los cuatro compresores y la variable de compresor
c_a["Compresor"] = "A"
c_b["Compresor"] = "B"
c_c["Compresor"] = "C"
c_d["Compresor"] = "D"
df_comp = pd.concat([c_a, c_b, c_c, c_d], ignore_index=True)
df_comp
# Out:
#          Presion  Temperatura  Frecuencia  Potencia_Medida  Potencia_Estimada  \
# 0       0.775748         16.9    0.000000        71.466562          77.432556
# 1       0.776315         16.6    0.000000        71.442768          77.498194
# 2       0.776784         16.6    0.000000        71.347653          77.477151
# 3       0.777093         16.4    0.000000        71.244807          77.524010
# 4       0.777436         16.4    0.000000        71.194101          77.508609
# ...          ...          ...         ...              ...                ...
# 176776  0.747784          8.9    4.021267        78.700917          80.606028
# 176777  0.747565          8.9    4.006250        78.568766          80.613163
# 176778  0.747156          8.5    4.007903        78.495658          80.855701
# 176779  0.745775          8.5    4.012087        78.643818          80.988209
# 176780  0.744913          8.3    4.269080        78.895376          81.396918
#
#        Compresor
# ...

# %%
logs=pd.read_csv("../Datos/Originales/Redes/Firewall_logs.csv")
logs
# Out:
#        Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# 0            57222                53            54587                    53
# 1            56258              3389            56258                  3389
# 2             6881             50321            43265                 50321
# 3            50553              3389            50553                  3389
# 4            50002               443            45848                   443
# ...            ...               ...              ...                   ...
# 65527        63691                80            13237                    80
# 65528        50964                80            13485                    80
# 65529        54871               445                0                     0
# 65530        54870               445                0                     0
# 65531        54867               445                0                     0
#
# ...

# %%
logs.describe()
# Out:
#         Source Port  Destination Port  NAT Source Port  NAT Destination Port  \
# count  65532.000000      65532.000000     65532.000000          65532.000000
# mean   49391.969343      10577.385812     19282.972761           2671.049930
# std    15255.712537      18466.027039     21970.689669           9739.162278
# min        0.000000          0.000000         0.000000              0.000000
# 25%    49183.000000         80.000000         0.000000              0.000000
# 50%    53776.500000        445.000000      8820.500000             53.000000
# 75%    58638.000000      15000.000000     38366.250000            443.000000
# max    65534.000000      65535.000000     65535.000000          65535.000000
#
#               Bytes    Bytes Sent  Bytes Received       Packets  \
# count  6.553200e+04  6.553200e+04    6.553200e+04  6.553200e+04
# mean   9.712395e+04  2.238580e+04    7.473815e+04  1.028660e+02
# std    5.618439e+06  3.828139e+06    2.463208e+06  5.133002e+03
# ...

# %%
c_a.describe()
# Out:
#             Presion   Temperatura    Frecuencia  Potencia_Medida  \
# count  39321.000000  39321.000000  39321.000000     39321.000000
# mean       0.770542     11.936001     18.072116        90.796443
# std        0.021078      6.053740     24.295732        15.561384
# min        0.735058     -2.200000      0.000000        69.618537
# 25%        0.749447      7.900000      0.000000        78.677732
# 50%        0.766375     11.600000      0.000000        82.456064
# 75%        0.792374     15.400000     32.641157       103.964637
# max        0.817415     36.300000    100.000000       125.416806
#
#        Potencia_Estimada
# count       39321.000000
# mean           90.945048
# std            15.676944
# min            72.431766
# 25%            78.513035
# 50%            81.775146
# 75%           102.020353
# max           125.000000

# %%
c_b.describe()
# Out:
#             Presion   Temperatura    Frecuencia  Potencia_Medida  \
# count  45966.000000  45966.000000  45966.000000     45966.000000
# mean       0.756487     12.457936     24.500749        88.683290
# std        0.008911      6.390871     24.536416        22.105677
# min        0.733322     -2.400000      0.000000        50.394369
# 25%        0.748004      7.900000      1.000000        68.197637
# 50%        0.756621     11.900000     18.000000        84.429360
# 75%        0.763981     16.400000     39.057050       106.868053
# max        0.778551     38.300000    100.000000       130.714054
#
#        Potencia_Estimada
# count       45966.000000
# mean           88.779733
# std            22.152432
# min            55.614709
# 25%            68.357159
# 50%            83.925539
# 75%           104.131590
# max           130.714054

# %%
c_c.describe()
# Out:
#             Presion   Temperatura    Frecuencia  Potencia_Medida  \
# count  49705.000000  49705.000000  49705.000000     49705.000000
# mean       0.755801     12.788935     26.707291        92.493392
# std        0.009212      7.020098     25.844649        21.725193
# min        0.727901     -3.200000      0.000000        54.588742
# 25%        0.747439      7.300000      1.115993        71.830079
# 50%        0.754395     12.200000     21.123530        88.936992
# 75%        0.762912     17.400000     42.720023       111.417753
# max        0.781873     39.000000    100.000000       131.274307
#
#        Potencia_Estimada
# count       49705.000000
# mean           92.631959
# std            21.824802
# min            58.852337
# 25%            71.805553
# 50%            89.326151
# 75%           108.926272
# max           131.274307

# %%
c_d.describe()
# Out:
#             Presion   Temperatura    Frecuencia  Potencia_Medida  \
# count  41789.000000  41789.000000  41789.000000     41789.000000
# mean       0.759691     12.852751     26.287229        95.829053
# std        0.012289      6.170078     26.868740        21.200003
# min        0.739489     -5.400000      0.000000        66.901101
# 25%        0.748131      8.800000      0.000000        75.862089
# 50%        0.759044     12.500000     20.380947        90.584560
# 75%        0.768456     16.800000     44.000000       115.395048
# max        0.789103     38.100000    100.000000       132.000000
#
#        Potencia_Estimada
# count       41789.000000
# mean           95.894564
# std            21.197227
# min            66.901101
# 25%            75.940139
# 50%            92.277313
# 75%           113.243740
# max           132.000000

# %%
df_comp.describe()
# Out:
#              Presion    Temperatura     Frecuencia  Potencia_Medida  \
# count  176781.000000  176781.000000  176781.000000    176781.000000
# mean        0.760178      12.528239      24.113553        91.913766
# std         0.014557       6.461401      25.640780        20.653660
# min         0.727901      -5.400000       0.000000        50.394369
# 25%         0.748172       7.900000       0.000000        74.887941
# 50%         0.757743      12.100000      17.000000        86.138320
# 75%         0.767126      16.600000      40.000000       108.978045
# max         0.817415      39.000000     100.000000       132.000000
#
#        Potencia_Estimada
# count      176781.000000
# mean           92.026343
# std            20.713235
# min            55.614709
# 25%            75.358058
# 50%            86.609357
# 75%           107.111876
# max           132.000000

# %% [markdown]
# DUPLICADOS

# %%
print(f"El compresor A tiene: {c_a.duplicated().sum()} duplicados")
print(f"El compresor B tiene: {c_b.duplicated().sum()} duplicados")
print(f"El compresor C tiene: {c_c.duplicated().sum()} duplicados")
print(f"El compresor D tiene: {c_d.duplicated().sum()} duplicados")
print(f"Firewall logs tiene: {logs.duplicated().sum()} duplicados")
# Out:
# El compresor A tiene: 0 duplicados
# El compresor B tiene: 0 duplicados
# El compresor C tiene: 6 duplicados
# El compresor D tiene: 5 duplicados
# Firewall logs tiene: 8362 duplicados

# %%
c_c.drop_duplicates(inplace=True)
c_d.drop_duplicates(inplace=True)
logs.drop_duplicates(inplace=True)

# %%
print(f"El compresor A tiene: {c_a.duplicated().sum()} duplicados")
print(f"El compresor B tiene: {c_b.duplicated().sum()} duplicados")
print(f"El compresor C tiene: {c_c.duplicated().sum()} duplicados")
print(f"El compresor D tiene: {c_d.duplicated().sum()} duplicados")
print(f"Firewall logs tiene: {logs.duplicated().sum()} duplicados")
# Out:
# El compresor A tiene: 0 duplicados
# El compresor B tiene: 0 duplicados
# El compresor C tiene: 0 duplicados
# El compresor D tiene: 0 duplicados
# Firewall logs tiene: 0 duplicados

# %% [markdown]
# MISSINGS

# %%
c_a.isnull().sum() # No hay missings
# Out:
# Presion              0
# Temperatura          0
# Frecuencia           0
# Potencia_Medida      0
# Potencia_Estimada    0
# Compresor            0
# dtype: int64

# %%
c_b.isnull().sum() # No hay missings
# Out:
# Presion              0
# Temperatura          0
# Frecuencia           0
# Potencia_Medida      0
# Potencia_Estimada    0
# Compresor            0
# dtype: int64

# %%
c_c.isnull().sum() # No hay missings
# Out:
# Presion              0
# Temperatura          0
# Frecuencia           0
# Potencia_Medida      0
# Potencia_Estimada    0
# Compresor            0
# dtype: int64

# %%
c_d.isnull().sum() # No hay missings
# Out:
# Presion              0
# Temperatura          0
# Frecuencia           0
# Potencia_Medida      0
# Potencia_Estimada    0
# Compresor            0
# dtype: int64

# %%
logs.isnull().sum() # No hay missings
# Out:
# Source Port             0
# Destination Port        0
# NAT Source Port         0
# NAT Destination Port    0
# Action                  0
# Bytes                   0
# Bytes Sent              0
# Bytes Received          0
# Packets                 0
# Elapsed Time (sec)      0
# pkts_sent               0
# pkts_received           0
# dtype: int64

# %% [markdown]
# GUARDAR CSV

# %%
df_comp = pd.concat([c_a, c_b, c_c, c_d], ignore_index=True)
print(f"El df de compresores tiene: {df_comp.duplicated().sum()} duplicados")
# Out:
# El df de compresores tiene: 0 duplicados

# %%
df_comp.to_csv("../Datos/Transformados/df_comp.csv", index=False)
logs.to_csv("../Datos/Transformados/logs.csv", index=False)
